# %% [markdown]
# # 03 - Optional: run the ablation grid on a Kaggle GPU (Day 10)
# The models are small enough for a laptop CPU (about 15 s per epoch on one core with cached embeddings), but a
# GPU session runs the full seed sweep in one go.

# %%
# !git clone -q https://github.com/<you>/tracewarden.git && pip -q install -e "tracewarden[dev]"
from huggingface_hub import snapshot_download
snapshot_download('<you>/tracewarden-cache', repo_type='dataset', local_dir='cache', allow_patterns=['mpnet/*'])

# %%
# %cd tracewarden
# !python scripts/run_ablation.py --data /kaggle/input/tw-data/processed --cache ../cache/mpnet --seeds 3 --out paper/results/ablation.md
